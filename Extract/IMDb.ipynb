# %% [markdown]
# # Google Scraping
# ---

# %%
import sys
sys.path.append('../')

import pandas as pd

import re
import time

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service

browser = webdriver.Chrome()

# %%
# !where chromedriver
# Out:
# d:\Applications\anaconda3\envs\cuda\chromedriver.exe

# %% [markdown]
# ### Scraping IMDB for Top 250 movies
# ___

# %%
# Initialize Chrome WebDriver (make sure you have chromedriver installed)
driver = webdriver.Chrome()

# Navigate to IMDb Top 250
url = "https://www.imdb.com/chart/top/"
driver.get(url)

# Wait for page to load and scroll down to load all movies
SCROLL_PAUSE_TIME = 2

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# Get page source after all content is loaded
soup = BeautifulSoup(driver.page_source, 'html.parser')

# Initialize lists to store data
movie_data = []

# Find all movie entries
movies = soup.find_all('li', class_='ipc-metadata-list-summary-item')

for movie in movies:
    movie_dict = {}
    
    # Extract title (remove ranking number from title)
    title = movie.find('h3', class_='ipc-title__text')
    if title:
        movie_dict['Title'] = title.text.strip()
    else:
        movie_dict['Title'] = 'Unknown'
    
    # Extract IMDB ID
    movie_link = movie.find('a', class_='ipc-title-link-wrapper')
    if movie_link:
        imdb_id = re.search(r'/title/(tt\d+)/', movie_link['href'])
        movie_dict['IMDb_ID'] = imdb_id.group(1) if imdb_id else 'Unknown'
    
    # Extract rating
    rating = movie.find('span', class_='ipc-rating-star--imdb')
    if rating:
        movie_dict['Rating'] = rating['aria-label'].split()[-1]
    
    # Extract year
    year = movie.find('span', class_='cli-title-metadata-item')
    movie_dict['Year'] = year.text if year else 'Unknown'
    
    movie_data.append(movie_dict)

# Close the browser
driver.quit()

# Create DataFrame
Raw_df = pd.DataFrame(movie_data)

# Display the data
print("Successfully scraped", len(Raw_df), "movies")
Raw_df.head()
# Out:
# Successfully scraped 250 movies
#                          Title    IMDb_ID Rating  Year
# 0  1. The Shawshank Redemption  tt0111161    9.3  1994
# 1             2. The Godfather  tt0068646    9.2  1972
# 2           3. The Dark Knight  tt0468569    9.0  2008
# 3     4. The Godfather Part II  tt0071562    9.0  1974
# 4              5. 12 Angry Men  tt0050083    9.0  1957

# %% [markdown]
# ### Separate 'Rank & Title' column to Rank and Title columns
# ---

# %%
# Extract rank numbers from title using str.extract()
Raw_df['Rank'] = Raw_df['Title'].str.extract(r'^(\d+)')

# Remove rank numbers and period from title 
Raw_df['Title'] = Raw_df['Title'].str.replace(r'^\d+\.\s*', '', regex=True)

# Reorder columns
Imdb_df = Raw_df[['Rank', 'Title', 'IMDb_ID', 'Year', 'Rating']]
Imdb_df.head()
# Out:
#   Rank                     Title    IMDb_ID  Year Rating
# 0    1  The Shawshank Redemption  tt0111161  1994    9.3
# 1    2             The Godfather  tt0068646  1972    9.2
# 2    3           The Dark Knight  tt0468569  2008    9.0
# 3    4     The Godfather Part II  tt0071562  1974    9.0
# 4    5              12 Angry Men  tt0050083  1957    9.0

# %% [markdown]
# ### Building the URL to scrape Google
# ---

# %%
movies = Imdb_df['Title']
movies = movies.str.replace(r"[,:'.]", '', regex=True)

# %%
base_url = 'https://www.google.com/search?&q='

movie_list = movies.str.lower().str.replace(' ', '+', n = -1, case=None, regex=True)

query_url=[]

for movie in movie_list:
    query_url.append(f'{base_url}{movie}+watch+movie')

# %%
google_query_url_df = pd.DataFrame({'Rank': Imdb_df['Rank'],
                                    'Title': Imdb_df['Title'],
                                    'Google Query URL' : query_url
                                   })

google_query_url_df = google_query_url_df.set_index(['Rank'])

google_query_url_df.head(10)
# Out:
#                                                   Title  \
# Rank
# 1                              The Shawshank Redemption
# 2                                         The Godfather
# 3                                       The Dark Knight
# 4                                 The Godfather Part II
# 5                                          12 Angry Men
# 6         The Lord of the Rings: The Return of the King
# 7                                      Schindler's List
# 8                                          Pulp Fiction
# 9     The Lord of the Rings: The Fellowship of the Ring
# 10                       The Good, the Bad and the Ugly
#
#                                        Google Query URL
# Rank
# 1     https://www.google.com/search?&q=the+shawshank...
# 2     https://www.google.com/search?&q=the+godfather...
# 3     https://www.google.com/search?&q=the+dark+knig...
# 4     https://www.google.com/search?&q=the+godfather...
# 5     https://www.google.com/search?&q=12+angry+men+...
# 6     https://www.google.com/search?&q=the+lord+of+t...
# 7     https://www.google.com/search?&q=schindlers+li...
# 8     https://www.google.com/search?&q=pulp+fiction+...
# 9     https://www.google.com/search?&q=the+lord+of+t...
# 10    https://www.google.com/search?&q=the+good+the+...

# %%
google_query_url_df.to_csv('../Output/IMDb/Google_Query_Url.csv')

# %% [markdown]
# #### Sample Google scraping
# ---

# %%
def find_imdb_url(browser, max_pages=5):
    imdb_pattern = r'https://www\.imdb\.com/title/[^/\s"]+'
    
    for page in range(max_pages):
        # Search in current page
        page_source = browser.page_source
        matches = re.findall(imdb_pattern, page_source)
        
        if matches:
            return matches[0]
            
        # Try next page if available
        try:
            next_button = browser.find_element(By.ID, 'pnnext')
            next_button.click()
            time.sleep(3)
        except:
            break
    return None

# Main scraping code
sample = 'The Godfather'
base_url = 'https://www.google.com/search?&q='
query_url = f'{base_url}{sample}+watch+movie'

try:
    browser.get(query_url)
    time.sleep(5)
    
    # Get streaming data
    soup = BeautifulSoup(browser.page_source, 'lxml')
    
    streaming = []
    title = []
    price = []

    results1 = soup.find_all('div', class_='ellip bclEt')
    for result in results1:
        streaming.append(result.text)
        title.append(sample.capitalize())

    results2 = soup.find_all('div', class_='ellip rsj3fb')
    for result in results2:
        price.append(result.text)
        
    # Find IMDb URL by scanning through pages
    imdb_url = find_imdb_url(browser)
    
    # Create DataFrame
    Sample_Streaming_df = pd.DataFrame({
        'Title': title,
        'Streaming On': streaming,
        'Price': price,
        'IMDb_URL': imdb_url
    })

    Sample_Streaming_df['Price'] = Sample_Streaming_df['Price'].str.replace("$","", case=True, regex=True)
    Sample_Streaming_df['Price'] = Sample_Streaming_df['Price'].str.replace("From ","", case=True, regex=True)

except Exception as e:
    print(f"Error: {e}")

Sample_Streaming_df
# Out:
#            Title             Streaming On         Price IMDb_URL
# 0  The godfather                  Netflix  Subscription     None
# 1  The godfather                    Vidio  Subscription     None
# 2  The godfather  Google Play Movies & TV  Rp 25.000,00     None
# 3  The godfather                 Apple TV  Rp 25.000,00     None

# %%
Sample_Streaming_df.to_csv('../Output/IMDb/Sample_Google_Scraping.csv')

# %% [markdown]
# ## Scraping Google
# ---

# %%
Streaming = []
Title = []
Price = []
IMDb_URLs = []

count = 0

movies = google_query_url_df['Title']

query_urls = google_query_url_df['Google Query URL']

base_url = 'https://www.google.com/search?&q='

# %%
def find_imdb_url(browser, max_pages=5):
    imdb_pattern = r'https://www\.imdb\.com/title/[^/\s"]+'
    
    for page in range(max_pages):
        # Search in current page
        page_source = browser.page_source
        matches = re.findall(imdb_pattern, page_source)
        
        if matches:
            return matches[0]
            
        # Try next page if available
        try:
            next_button = browser.find_element(By.ID, 'pnnext')
            next_button.click()
            time.sleep(2)
        except:
            break
    return None

# Loop through all movies in the query list
for count in range(len(movies)):
    try:
        # Construct and visit URL
        query_url = f'{base_url}{movies[count]}+watch+movie'
        browser.get(query_url)
        time.sleep(2)
        
        soup = BeautifulSoup(browser.page_source, 'lxml')

        # Look for streaming services
        results1 = soup.find_all('div', class_='ellip bclEt')
        if results1:
            for result in results1:
                Streaming.append(result.text)
                Title.append(movies[count].capitalize())
                
                price_div = soup.find('div', class_='ellip rsj3fb')
                Price.append(price_div.text if price_div else 'Not Available')
                
                # Find IMDb URL for each streaming entry
                imdb_url = find_imdb_url(browser)
                IMDb_URLs.append(imdb_url)
                
                # Return to original search results
                browser.get(query_url)
                time.sleep(2)
        else:
            Title.append(movies[count].capitalize())
            Streaming.append('Not Available') 
            Price.append('Not Available')
            IMDb_URLs.append('Not Available')
            
        print(f"Processed {count + 1}/250: {movies[count]}")
            
    except Exception as e:
        print(f"Error processing {movies[count]}: {str(e)}")
        Title.append(movies[count].capitalize())
        Streaming.append('Error')
        Price.append('Error')
        IMDb_URLs.append('Error')
        continue
        
    # Save progress periodically
    if count % 50 == 0 and count > 0:
        temp_df = pd.DataFrame({
            'Title': Title,
            'Streaming On': Streaming, 
            'Price': Price,
            'IMDb_URL': IMDb_URLs
        })
        temp_df.to_csv(f'../Output/IMDb/Google_Checkpoints/Google_Scraping_checkpoint_{count}.csv', index=False)

# Create final dataframe
Streaming_df = pd.DataFrame({
    'Title': Title,
    'Streaming On': Streaming,
    'Price': Price,
    'IMDb_URL': IMDb_URLs
})

# Save complete results
Streaming_df.to_csv('../Output/IMDb/Google_Checkpoints/Google_Scraping_complete.csv', index=False)

print(f"Completed processing {len(movies)} movies")
# Out:
# C:\Users\MASTER CORE\AppData\Local\Temp\ipykernel_46720\661329691.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   query_url = f'{base_url}{movies[count]}+watch+movie'
# C:\Users\MASTER CORE\AppData\Local\Temp\ipykernel_46720\661329691.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Title.append(movies[count].capitalize())
# C:\Users\MASTER CORE\AppData\Local\Temp\ipykernel_46720\661329691.py:54: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Processed {count + 1}/250: {movies[count]}")
# Processed 1/250: The Shawshank Redemption
# Processed 2/250: The Godfather
# Processed 3/250: The Dark Knight
# Processed 4/250: The Godfather Part II
# Processed 5/250: 12 Angry Men
# Processed 6/250: The Lord of the Rings: The Return of the King
# Processed 7/250: Schindler's List
# Processed 8/250: Pulp Fiction
# Processed 9/250: The Lord of the Rings: The Fellowship of the Ring
# Processed 10/250: The Good, the Bad and the Ugly
# Processed 11/250: Forrest Gump
# Processed 12/250: The Lord of the Rings: The Two Towers
# C:\Users\MASTER CORE\AppData\Local\Temp\ipykernel_46720\661329691.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Title.append(movies[count].capitalize())
# Processed 13/250: Fight Club
# Processed 14/250: Inception
# Processed 15/250: Star Wars: Episode V - The Empire Strikes Back
# Processed 16/250: The Matrix
# Processed 17/250: GoodFellas
# Processed 18/250: One Flew Over the Cuckoo's Nest
# Processed 19/250: Interstellar
# Processed 20/250: Seven
# Processed 21/250: It's a Wonderful Life
# Processed 22/250: Seven Samurai
# Processed 23/250: The Silence of the Lambs
# Processed 24/250: Saving Private Ryan
# Processed 25/250: City of God
# Processed 26/250: The Green Mile
# Processed 27/250: Life Is Beautiful
# Processed 28/250: Terminator 2: Judgment Day
# Processed 29/250: Star Wars: Episode IV - A New Hope
# Processed 30/250: Back to the Future
# Processed 31/250: Spirited Away
# Processed 32/250: The Pianist
# Processed 33/250: Parasite
# Processed 34/250: Psycho
# Processed 35/250: Gladiator
# Processed 36/250: The Lion King
# Processed 37/250: The Departed
# Processed 38/250: Spider-Man: Across the Spider-Verse
# Processed 39/250: Grave of the Fireflies
# Processed 40/250: Whiplash
# Processed 41/250: American History X
# Processed 42/250: Leon
# Processed 43/250: The Prestige
# Processed 44/250: Harakiri
# Processed 45/250: Casablanca
# Processed 46/250: The Usual Suspects
# Processed 47/250: Untouchable
# Processed 48/250: Cinema Paradiso
# Processed 49/250: Dune: Part Two
# Processed 50/250: Modern Times
# Processed 51/250: Alien
# Processed 52/250: Rear Window
# Processed 53/250: Once Upon a Time in the West
# Processed 54/250: Django Unchained
# Processed 55/250: City Lights
# Processed 56/250: Apocalypse Now
# Processed 57/250: Memento
# Processed 58/250: WALL·E
# Processed 59/250: Raiders of the Lost Ark
# Processed 60/250: The Lives of Others
# Processed 61/250: 12th Fail
# Processed 62/250: Sunset Blvd.
# Processed 63/250: Avengers: Infinity War
# Processed 64/250: Paths of Glory
# Processed 65/250: Spider-Man: Into the Spider-Verse
# Processed 66/250: Witness for the Prosecution
# Processed 67/250: The Shining
# Processed 68/250: The Great Dictator
# Processed 69/250: Aliens
# Processed 70/250: Inglourious Basterds
# Processed 71/250: The Dark Knight Rises
# Processed 72/250: Coco
# Processed 73/250: Amadeus
# Processed 74/250: Toy Story
# Processed 75/250: Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Processed 76/250: Oldboy
# Processed 77/250: American Beauty
# Processed 78/250: Avengers: Endgame
# Processed 79/250: Das Boot
# Processed 80/250: Good Will Hunting
# Processed 81/250: Braveheart
# Processed 82/250: Princess Mononoke
# Processed 83/250: Your Name.
# Processed 84/250: Joker
# Processed 85/250: High and Low
# Processed 86/250: 3 Idiots
# Processed 87/250: Once Upon a Time in America
# Processed 88/250: Singin' in the Rain
# Processed 89/250: Capernaum
# Processed 90/250: Come and See
# Processed 91/250: Requiem for a Dream
# Processed 92/250: Toy Story 3
# Processed 93/250: Star Wars: Episode VI - Return of the Jedi
# Processed 94/250: The Hunt
# Processed 95/250: Eternal Sunshine of the Spotless Mind
# Processed 96/250: Ikiru
# Processed 97/250: 2001: A Space Odyssey
# Processed 98/250: Reservoir Dogs
# Processed 99/250: Lawrence of Arabia
# Processed 100/250: The Apartment
# Processed 101/250: Incendies
# Processed 102/250: Scarface
# Processed 103/250: North by Northwest
# Processed 104/250: Double Indemnity
# Processed 105/250: Citizen Kane
# Processed 106/250: M
# Processed 107/250: Vertigo
# Processed 108/250: Heat
# Processed 109/250: Full Metal Jacket
# Processed 110/250: Oppenheimer
# Processed 111/250: Up
# Processed 112/250: Amélie
# Processed 113/250: A Clockwork Orange
# Processed 114/250: To Kill a Mockingbird
# Processed 115/250: A Separation
# Processed 116/250: The Sting
# Processed 117/250: Die Hard
# Processed 118/250: Indiana Jones and the Last Crusade
# Processed 119/250: Like Stars on Earth
# Processed 120/250: Metropolis
# Processed 121/250: Snatch
# Processed 122/250: 1917
# Processed 123/250: L.A. Confidential
# Processed 124/250: Bicycle Thieves
# Processed 125/250: Downfall
# Processed 126/250: Hamilton
# Processed 127/250: Taxi Driver
# Processed 128/250: Dangal
# Processed 129/250: The Wolf of Wall Street
# Processed 130/250: Batman Begins
# Processed 131/250: For a Few Dollars More
# Processed 132/250: Green Book
# Processed 133/250: Some Like It Hot
# Processed 134/250: The Truman Show
# Processed 135/250: Judgment at Nuremberg
# Processed 136/250: The Kid
# Processed 137/250: The Father
# Processed 138/250: Shutter Island
# Processed 139/250: All About Eve
# Processed 140/250: There Will Be Blood
# Processed 141/250: Jurassic Park
# Processed 142/250: Casino
# Processed 143/250: Top Gun: Maverick
# Processed 144/250: The Sixth Sense
# Processed 145/250: Ran
# Processed 146/250: Pan's Labyrinth
# Processed 147/250: No Country for Old Men
# Processed 148/250: Unforgiven
# Processed 149/250: The Thing
# Processed 150/250: A Beautiful Mind
# Processed 151/250: Kill Bill: Vol. 1
# Processed 152/250: The Wild Robot
# Processed 153/250: The Treasure of the Sierra Madre
# Processed 154/250: Yojimbo
# Processed 155/250: Prisoners
# Processed 156/250: The Great Escape
# Processed 157/250: Finding Nemo
# Processed 158/250: Monty Python and the Holy Grail
# Processed 159/250: Howl's Moving Castle
# Processed 160/250: The Elephant Man
# Processed 161/250: Rashomon
# Processed 162/250: Dial M for Murder
# Processed 163/250: Gone with the Wind
# Processed 164/250: Chinatown
# Processed 165/250: The Secret in Their Eyes
# Processed 166/250: Lock, Stock and Two Smoking Barrels
# Processed 167/250: Inside Out
# Processed 168/250: V for Vendetta
# Processed 169/250: Three Billboards Outside Ebbing, Missouri
# Processed 170/250: Raging Bull
# Processed 171/250: Klaus
# Processed 172/250: Trainspotting
# Processed 173/250: The Bridge on the River Kwai
# Processed 174/250: Catch Me If You Can
# Processed 175/250: Fargo
# Processed 176/250: Warrior
# Processed 177/250: Spider-Man: No Way Home
# Processed 178/250: Gran Torino
# Processed 179/250: Harry Potter and the Deathly Hallows: Part 2
# Processed 180/250: Million Dollar Baby
# Processed 181/250: My Neighbour Totoro
# Processed 182/250: Mad Max: Fury Road
# Processed 183/250: Ben-Hur
# Processed 184/250: Children of Heaven
# Processed 185/250: Barry Lyndon
# Processed 186/250: 12 Years a Slave
# Processed 187/250: Blade Runner
# Processed 188/250: Before Sunrise
# Processed 189/250: The Grand Budapest Hotel
# Processed 190/250: Hacksaw Ridge
# Processed 191/250: Dead Poets Society
# Processed 192/250: Gone Girl
# Processed 193/250: Memories of Murder
# Processed 194/250: In the Name of the Father
# Processed 195/250: The Gold Rush
# Processed 196/250: Maharaja
# Processed 197/250: Monsters, Inc.
# Processed 198/250: Wild Tales
# Processed 199/250: Ratatouille
# Processed 200/250: The Deer Hunter
# Processed 201/250: How to Train Your Dragon
# Processed 202/250: Jaws
# Processed 203/250: Sherlock Jr.
# Processed 204/250: The General
# Processed 205/250: Mary and Max
# Processed 206/250: On the Waterfront
# Processed 207/250: The Wages of Fear
# Processed 208/250: Le Mans '66
# Processed 209/250: Wild Strawberries
# Processed 210/250: Mr. Smith Goes to Washington
# Processed 211/250: The Third Man
# Processed 212/250: Logan
# Processed 213/250: Rocky
# Processed 214/250: Tokyo Story
# Processed 215/250: The Big Lebowski
# Processed 216/250: The Seventh Seal
# Processed 217/250: Room
# Processed 218/250: Spotlight
# Processed 219/250: The Terminator
# Processed 220/250: Hotel Rwanda
# Processed 221/250: Platoon
# Processed 222/250: Pirates of the Caribbean: The Curse of the Black Pearl
# Processed 223/250: La haine
# Processed 224/250: Jai Bhim
# Processed 225/250: Before Sunset
# Processed 226/250: The Passion of Joan of Arc
# Processed 227/250: The Best Years of Our Lives
# Processed 228/250: The Exorcist
# Processed 229/250: Rush
# Processed 230/250: A Man Escaped
# Processed 231/250: The Incredibles
# Processed 232/250: The Wizard of Oz
# Processed 233/250: Network
# Processed 234/250: Stand by Me
# Processed 235/250: Hachi: A Dog's Tale
# Processed 236/250: The Sound of Music
# Processed 237/250: My Father and My Son
# Processed 238/250: To Be or Not to Be
# Processed 239/250: The Handmaiden
# Processed 240/250: Into the Wild
# Processed 241/250: The Battle of Algiers
# Processed 242/250: The Iron Giant
# Processed 243/250: The Grapes of Wrath
# Processed 244/250: Groundhog Day
# Processed 245/250: Amores perros
# Processed 246/250: Rebecca
# Processed 247/250: The Help
# Processed 248/250: Cool Hand Luke
# Processed 249/250: A Silent Voice
# Processed 250/250: Paris, Texas
# Completed processing 250 movies

# %%
browser.quit()

# %%
Streaming_df = pd.DataFrame({'Title': Title,
                             'Streaming On' : Streaming,
                             'Price' : Price,
                             'IMDb_URL': IMDb_URLs
                            })

# %%
Streaming_df.head
# Out:
# <bound method NDFrame.head of                         Title             Streaming On              Price  \
# 0    The shawshank redemption                      Max       Subscription
# 1    The shawshank redemption                 Apple TV       Subscription
# 2               The godfather                  Netflix       Subscription
# 3               The godfather                    Vidio       Subscription
# 4               The godfather  Google Play Movies & TV       Subscription
# ..                        ...                      ...                ...
# 350                  The help            Not Available      Not Available
# 351            Cool hand luke                 Apple TV  From Rp 25.000,00
# 352            Cool hand luke  Google Play Movies & TV  From Rp 25.000,00
# 353            A silent voice                  Netflix       Subscription
# 354              Paris, texas            Not Available      Not Available
#
#                                  IMDb_URL
# 0    https://www.imdb.com/title/tt0111161
# 1    https://www.imdb.com/title/tt0111161
# 2                                    None
# 3                                    None
# 4                                    None
# ..                                    ...
# 350                         Not Available
# 351  https://www.imdb.com/title/tt0061512
# 352  https://www.imdb.com/title/tt0061512
# 353  https://www.imdb.com/title/tt5323662
# 354                         Not Available
#
# [355 rows x 4 columns]>

# %% [markdown]
# Data Cleaning

# %%
Streaming_df_cleaned = Streaming_df.dropna(how='any')  # Remove rows with any null values

# Clean up text fields
Streaming_df_cleaned['Title'] = (Streaming_df_cleaned['Title']
    .str.strip()  # Remove leading/trailing whitespace
    .str.title()  # Consistent capitalization
)

Streaming_df_cleaned['Streaming On'] = (Streaming_df_cleaned['Streaming On']
    .str.strip()
    .str.replace('  ', ' ')  # Remove double spaces
)

# Clean up price field
Streaming_df_cleaned['Price'] = (Streaming_df_cleaned['Price']
    .str.replace('Rp', '', regex=False)  # Remove dollar signs
    .str.replace('Dari ', '', regex=False)  # Remove "From " text
    .str.strip()
)

# Clean IMDb URLs and extract IDs
Streaming_df_cleaned['IMDb_URL'] = (Streaming_df_cleaned['IMDb_URL']
    .str.strip()
    .str.rstrip('/')  # Remove trailing slashes
)

# Extract IMDb ID using regex
Streaming_df_cleaned['imdb_id'] = (Streaming_df_cleaned['IMDb_URL']
    .str.extract(r'title/(tt\d+)', expand=False)  # Extract ttXXXXXXX pattern
    .fillna('Not Available')  # Handle missing/invalid URLs
)

# Verify IMDb IDs are in correct format
Streaming_df_cleaned.loc[~Streaming_df_cleaned['imdb_id'].str.match(r'^tt\d+$|^Not Available$'), 'imdb_id'] = 'Invalid Format'

# Drop IMDb_URL column
Streaming_df_cleaned = Streaming_df_cleaned.drop('IMDb_URL', axis=1)

# Remove duplicate entries
Streaming_df_cleaned = Streaming_df_cleaned.drop_duplicates()

# Reset index after all cleaning
Streaming_df_cleaned = Streaming_df_cleaned.reset_index(drop=True)
# Out:
# C:\Users\MASTER CORE\AppData\Local\Temp\ipykernel_46720\612464932.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Streaming_df_cleaned['Title'] = (Streaming_df_cleaned['Title']
# C:\Users\MASTER CORE\AppData\Local\Temp\ipykernel_46720\612464932.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Streaming_df_cleaned['Streaming On'] = (Streaming_df_cleaned['Streaming On']
# C:\Users\MASTER CORE\AppData\Local\Temp\ipykernel_46720\612464932.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Streaming_df_cleaned['Price'] = (Streaming_df_cleaned['Price']
# C:\Users\MASTER CORE\AppData\Local\Temp\ipykernel_46720\612464932.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Streaming_df_cleaned['IMDb_URL'] = (Streaming_df_cleaned['IMDb_URL']
# C:\Users\MASTER CORE\AppData\Local\Temp\ipykernel_46720\612464932.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Streaming_df_cleaned['imdb_id'] = (Streaming_df_cleaned['IMDb_URL']

# %%
Streaming_df_cleaned
# Out:
#                         Title             Streaming On            Price  \
# 0    The Shawshank Redemption                      Max     Subscription
# 1    The Shawshank Redemption                 Apple TV     Subscription
# 2             The Dark Knight                      Max     Subscription
# 3             The Dark Knight  Google Play Movies & TV     Subscription
# 4             The Dark Knight                 Apple TV     Subscription
# ..                        ...                      ...              ...
# 285                  The Help            Not Available    Not Available
# 286            Cool Hand Luke                 Apple TV  From  25.000,00
# 287            Cool Hand Luke  Google Play Movies & TV  From  25.000,00
# 288            A Silent Voice                  Netflix     Subscription
# 289              Paris, Texas            Not Available    Not Available
#
#            imdb_id
# 0        tt0111161
# 1        tt0111161
# 2        tt0468569
# 3        tt0468569
# 4        tt0468569
# ..             ...
# 285  Not Available
# 286      tt0061512
# 287      tt0061512
# 288      tt5323662
# 289  Not Available
#
# [290 rows x 4 columns]

# %%
Streaming_df_cleaned.to_csv('../Output/IMDb/Google_Scraping_Cleaned_Complete.csv', index=False)

# %%
import os
os.getcwd()
# Out:
# 'e:\\VSCProjects\\ETL-Melodi\\Extract'
